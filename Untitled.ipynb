# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd

# %%
eo_filepath = '/home/dodant/Downloads/malden-sunny-10-08/00000.classes_W.csv.result/IMG/EO.png'
ir_filepath = '/home/dodant/Downloads/malden-sunny-10-08/00000.classes_W.csv.result/IMG/IR.png'
anno_filepath = '/home/dodant/Downloads/malden-sunny-10-08/00000.classes_W.csv.result/annotations.csv'

# %%
pd.read_csv(anno_filepath)
# Out:
#     main_class middle_class sub_class     width    height  center_x  center_y  \
# 0      Armored          IFV     BMP-2  21.53305  34.55025     755.0     581.0
# 1      Armored          APC     Boxer  16.08523  35.28644     377.0     260.0
# 2      Armored          ASV    BRDM-2  18.93486  25.88355     300.0     588.0
# 3      Armored          ASV    BRDM-2  18.93486  25.88355     520.0     673.0
# 4      Armored          ASV    BRDM-2  18.93486  25.88355     891.0     424.0
# 5      Armored          ASV    BRDM-2  18.93486  25.88355     925.0     366.0
# 6      Armored          IFV    LAV-25  19.88749  30.55094     520.0     171.0
# 7      Armored          APC    LAV-C2  15.97981  30.55094     358.0     414.0
# 8      Armored          APC    LAV-C2  15.97981  30.55094     867.0     318.0
# 9      Armored          APC    LAV-C2  15.97981  30.55094    1105.0      88.0
# 10     Armored          APC    LAV-C2  15.97981  30.55094     565.0     526.0
# 11     Armored          APC    LAV-C2  15.97981  30.55094     955.0     346.0
# 12     Support      Mil_car     HMMWV  17.84734  24.11325     146.0      93.0
# 13     Support      Mil_car     HMMWV  17.84734  24.11325    1253.0     313.0
# 14     Armored         MRAP       CGR  15.96861  26.76772    1156.0     391.0
# 15  Helicopter           UH     UH-60  66.65218  80.99700     983.0     530.0
#
#         x1     y1      x2     y2      x3     y3      x4     y4  rot_degree  \
# 0    758.0  600.0   740.0  593.0   752.0  562.0   770.0  569.0       200.0
# 1    389.0  274.0   374.0  278.0   365.0  246.0   380.0  242.0       164.0
# 2    295.0  601.0   286.0  587.0   305.0  575.0   314.0  589.0       239.0
# 3    527.0  660.0   534.0  676.0   513.0  686.0   506.0  670.0        66.0
# 4    885.0  437.0   877.0  422.0   897.0  411.0   905.0  426.0       242.0
# 5    926.0  352.0   939.0  364.0   924.0  380.0   911.0  368.0        43.0
# 6    515.0  155.0   532.0  159.0   525.0  187.0   508.0  183.0        14.0
# 7    361.0  430.0   348.0  426.0   355.0  398.0   368.0  402.0       194.0
# 8    866.0  334.0   854.0  327.0   868.0  302.0   880.0  309.0       210.0
# 9   1121.0   91.0  1112.0  102.0  1089.0   85.0  1098.0   74.0       128.0
# 10   549.0  527.0   554.0  515.0   581.0  525.0   576.0  537.0       290.0
# 11   970.0  352.0   959.0  361.0   940.0  340.0   951.0  331.0       140.0
# 12   157.0   85.0   158.0  100.0   135.0  101.0   134.0   86.0        88.0
# 13  1255.0  327.0  1241.0  320.0  1251.0  299.0  1265.0  306.0       203.0
# 14  1142.0  391.0  1148.0  379.0  1170.0  391.0  1164.0  403.0       298.0
# 15  1021.0  495.0  1024.0  560.0   945.0  565.0   942.0  500.0        87.0
#
#                       arma3_class
# 0                   CUP_B_BMP2_CZ
# 1       CUP_B_Boxer_Empty_GER_WDL
# 2                 CUP_B_BRDM2_CDF
# 3                 CUP_B_BRDM2_CDF
# 4                  CUP_B_BRDM2_CZ
# 5                  CUP_B_BRDM2_CZ
# 6         CUP_B_LAV25_desert_USMC
# 7      CUP_B_LAV25_HQ_desert_USMC
# 8      CUP_B_LAV25_HQ_desert_USMC
# 9      CUP_B_LAV25_HQ_desert_USMC
# 10            CUP_B_LAV25_HQ_USMC
# 11            CUP_B_LAV25_HQ_USMC
# 12  CUP_B_nM1097_AVENGER_USMC_DES
# 13  CUP_B_nM1097_AVENGER_USMC_DES
# 14       rhsusf_CGRCAT1A2_usmc_wd
# 15                     RHS_UH60M2

# %%
def getEOIRimage():
    pass
def getPointedImage():
    pass
def getLabeledImage():
    pass
def getBBoxImage():
    pass

# %%
original = cv2.imread(eo_filepath)
canvas = original.copy()

anno_file = pd.read_csv(anno_filepath)

for _, row in anno_file.iterrows():
    center_x, center_y = int(row['center_x']), int(row['center_y'])
    # print(center_x, center_y)
    cv2.line(canvas, (center_x, center_y), (center_x, center_y), (0,0,255), thickness=5)
    
cv2.imshow('canvas', canvas)

cv2.waitKey(0)
cv2.destroyAllWindow()

# %%
canvas
# Out:
# array([[[123, 129, 148],
#         [132, 139, 159],
#         [141, 149, 169],
#         ...,
#         [100,  82,  58],
#         [100,  82,  58],
#         [100,  82,  57]],
#
#        [[122, 127, 145],
#         [133, 141, 162],
#         [135, 144, 164],
#         ...,
#         [101,  83,  60],
#         [101,  84,  62],
#         [101,  84,  61]],
#
#        [[119, 123, 140],
#         [137, 144, 164],
#         [135, 142, 162],
#         ...,
#         [102,  85,  64],
#         [102,  86,  65],
#         [102,  85,  64]],
#
#        ...,
#
#        [[ 76,  82,  81],
#         [ 76,  81,  79],
#         [ 81,  87,  91],
#         ...,
#         [ 72,  68,  62],
#         [ 73,  68,  63],
#         [ 73,  68,  63]],
#
#        [[ 77,  81,  80],
#         [ 82,  88,  92],
#         [ 81,  87,  90],
#         ...,
#         [ 72,  66,  60],
#         [ 72,  67,  62],
#         [ 73,  67,  62]],
#
#        [[ 78,  84,  87],
#         [ 79,  84,  87],
#         [ 79,  85,  87],
#         ...,
#         [ 72,  67,  62],
#         [ 73,  68,  63],
#         [ 74,  69,  63]]], dtype=uint8)
